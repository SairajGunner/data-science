# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

# %%
df = pd.read_csv("../data/original/world food production.csv")
# df_population = pd.read_csv("./data/world_population.csv")
# df_food_price = pd.read_csv("./data/wfp_food_prices_database.csv")
# df_currency_rates = pd.read_csv("./data/currency_to_usd.csv")

# %%
df.head(10)
# Out:
#         Entity  Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 0  Afghanistan  1961                   700000.0                    319000.0
# 1  Afghanistan  1962                   700000.0                    319000.0
# 2  Afghanistan  1963                   713000.0                    319000.0
# 3  Afghanistan  1964                   720000.0                    380000.0
# 4  Afghanistan  1965                   720000.0                    380000.0
# 5  Afghanistan  1966                   720000.0                    337000.0
# 6  Afghanistan  1967                   768000.0                    396000.0
# 7  Afghanistan  1968                   773000.0                    402000.0
# 8  Afghanistan  1969                   785000.0                    407000.0
# 9  Afghanistan  1970                   667000.0                    366000.0
#
#    Yams  Production (tonnes)  Wheat Production (tonnes)  \
# 0                  7467702.0                  2279000.0
# ...

# %%
df.shape
# Out:
# (11912, 24)

# %%
df.isna().sum()
# Out:
# Entity                                 0
# Year                                   0
# Maize Production (tonnes)              0
# Rice  Production ( tonnes)             0
# Yams  Production (tonnes)              0
# Wheat Production (tonnes)              0
# Tomatoes Production (tonnes)           0
# Tea  Production ( tonnes )             0
# Sweet potatoes  Production (tonnes)    0
# Sunflower seed  Production (tonnes)    0
# Sugar cane Production (tonnes)         0
# Soybeans  Production (tonnes)          0
# Rye  Production (tonnes)               0
# Potatoes  Production (tonnes)          0
# Oranges  Production (tonnes)           0
# Peas, dry Production ( tonnes)         0
# Palm oil  Production (tonnes)          0
# Grapes  Production (tonnes)            0
# Coffee, green Production ( tonnes)     0
# Cocoa beans Production (tonnes)        0
# Meat, chicken  Production (tonnes)     0
# Bananas  Production ( tonnes)          0
# Avocados Production (tonnes)           0
# ...

# %%
df["Year"].unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021], dtype=int64)

# %%
len(df[df["Year"] == 2018])
# Out:
# 214

# %%
df["Entity"].nunique()
# Out:
# 226

# %%
df.groupby(["Year"])["Year"].count() == 215 #used .max() to find out the highest value - using 2020 as the year.
# Out:
# Year
# 1961    False
# 1962    False
# 1963    False
# 1964    False
# 1965    False
#         ...
# 2017    False
# 2018    False
# 2019    False
# 2020     True
# 2021     True
# Name: Year, Length: 61, dtype: bool

# %%
df = df[df["Year"] == 2020]

# %%
df.shape
# Out:
# (215, 24)

# %%
df.head()
# Out:
#            Entity  Year  Maize Production (tonnes)  \
# 59    Afghanistan  2020                   271776.0
# 120        Africa  2020                 93972616.0
# 181  Africa (FAO)  2020                 93972616.0
# 242       Albania  2020                   399125.0
# 303       Algeria  2020                     3221.0
#
#      Rice  Production ( tonnes)  Yams  Production (tonnes)  \
# 59                    439549.00                73082370.00
# 120                 36201644.00                73082370.00
# 181                 36201644.00                 1046000.20
# 242                        0.00                     138.97
# 303                      314.75                  184457.61
#
#      Wheat Production (tonnes)  Tomatoes Production (tonnes)  \
# 59                   5185000.0                    22085254.0
# 120                 25367622.0                    22085254.0
# 181                 25367622.0                      313109.0
# ...

# %% [markdown]
# Remove Yams, Sunflower Seeds, Sugar cane, Rye, Grapes
#
# The Food Price dataset does not contain the above food items

# %%
df.drop(axis=1, inplace=True, columns=["Yams Production (tonnes)", "Sunflower seed Production (tonnes)", "Sugar cane Production (tonnes)", "Rye  Production (tonnes)", "Grapes Production (tonnes)"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.drop(axis=1, inplace=True, columns=["Yams Production (tonnes)", "Sunflower seed Production (tonnes)", "Sugar cane Production (tonnes)", "Rye  Production (tonnes)", "Grapes Production (tonnes)"])
#
# File c:\Users\saira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
# ...
